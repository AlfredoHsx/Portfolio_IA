# %% [markdown]
# # Programando Práctica #1 "flores" el perceptron simple

# %%
import pandas as pd
import numpy as np

from tensorflow import keras

# %%
#Leer el archivo
df = pd.read_csv("flores.csv")
df.head(5)
# Out:
#    Alto  Ancho  Targets
# 0   5.1    3.5        0
# 1   4.9    3.0        0
# 2   4.7    3.2        0
# 3   4.6    3.1        0
# 4   5.0    3.6        0

# %%
#Separar variables de los objetivos Altos y Ancho, objetivos valores 0 y 1 de la (última columna)
x=df.iloc[:, :2].values
y=df.iloc[:, -1].values
print(x.shape, len(y))
# Out:
# (100, 2) 100

# %%
#Dividir conjunto de datos 1. Probar y 2. Entrenar
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 41)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (80, 2) (80,)
# (20, 2) (20,)

# %%
#Crear el (M O D E L O) PERCEPTRON SIMPLE
model = keras.Sequential([
    keras.layers.Dense (1, activation = "tanh", input_shape=(2,)) #sigmoid, relu, tanh Funciones de activacion. ("sigmoid" ES PARA UNA MEJOR CLASIFICACION BINARIA)
])
print(model.summary())

model.compile(loss = keras.losses.BinaryCrossentropy(),optimizer = keras.optimizers.SGD(), metrics = ["accuracy"])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Entrenar el modelo.
history = model.fit(X_train, y_train, epochs = 20)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 0s 4ms/step - loss: 0.3028 - accuracy: 0.9875
# Epoch 2/20
# 3/3 [==============================] - 0s 755us/step - loss: 0.2976 - accuracy: 0.9500
# Epoch 3/20
# 3/3 [==============================] - 0s 779us/step - loss: 0.2819 - accuracy: 0.9500
# Epoch 4/20
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2819 - accuracy: 0.9875
# Epoch 5/20
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2725 - accuracy: 0.9875
# Epoch 6/20
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9500
# Epoch 7/20
# 3/3 [==============================] - 0s 121us/step - loss: 0.2683 - accuracy: 0.9750
# Epoch 8/20
# 3/3 [==============================] - 0s 0s/step - loss: 0.2619 - accuracy: 0.9875
# Epoch 9/20
# 3/3 [==============================] - 0s 0s/step - loss: 0.2614 - accuracy: 0.9625
# Epoch 10/20
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2566 - accuracy: 0.9750
# Epoch 11/20
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.9500
# Epoch 12/20
# 3/3 [==============================] - 0s 885us/step - loss: 0.2497 - accuracy: 0.9750
# Epoch 13/20
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2560 - accuracy: 0.9750
# Epoch 14/20
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2482 - accuracy: 0.9625
# Epoch 15/20
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2484 - accuracy: 0.9750
# Epoch 16/20
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2408 - accuracy: 0.9875
# Epoch 17/20
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2383 - accuracy: 0.9875
# Epoch 18/20
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2324 - accuracy: 0.9625
# Epoch 19/20
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2390 - accuracy: 0.9625
# Epoch 20/20
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2363 - accuracy: 0.9875

# %%
#Ver los resultados
print(model.evaluate(X_test, y_test))
# Out:
# 1/1 [==============================] - 0s 116ms/step - loss: 0.1514 - accuracy: 1.0000
# [0.1514240801334381, 1.0]

# %%
#Evaluar el modelo y ver su presición y saber si es confiable.
sample = X_test[4, :]
prediction = model.predict(np.expand_dims(sample,axis=0))

prediction = 0 if prediction<=0.5 else 1

print(prediction)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1

# %%
print(y_test [4]== prediction)
# Out:
# True

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=[112,8])
plt.scatter(df.iloc[:,0].values,df.iloc[:,1].values,
            c= df.iloc[:,-1].values)
plt.show()

# %%
values=pd.DataFrame(history.history)
values.plot()
plt.show()

# %%
#relu, tangente hyperbolica
