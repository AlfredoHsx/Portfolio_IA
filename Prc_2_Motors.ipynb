# %% [markdown]
# # Práctica #2 Motors

# %%
import pandas as pd
import numpy as np
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from keras.layers import LeakyReLU

# %%
# Leer el archivo CSV
df = pd.read_csv("car_motors.csv")
df.head(5)
# Mostrar las primeras filas del dataframe
df.head(5)
# Out:
#    Aceleracion    Fuerza  Labels
# 0     3.194978 -1.573232       1
# 1    -3.525748  0.866075       1
# 2     1.927721  3.666656       0
# 3     3.305401 -1.335324       1
# 4    -0.678097 -3.872477       0

# %%
# Separar variables y etiquetas
#x = df[['Aceleracion', 'Fuerza']].values
#y = df['Labels'].values
x=df.iloc[:, :2].values
y=df.iloc[:, -1].values

print(x.shape, len(y))
# Out:
# (200, 2) 200

# %%
#Dividir conjunto de datos 1. Probar y 2. Entrenar
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 30)


scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)



# Ejemplo de sobremuestreo de la clase minoritariaA
X_train_resampled, y_train_resampled = resample(X_train, y_train)


print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (160, 2) (160,)
# (40, 2) (40,)

# %%
#Crear el (M O D E L O) PERCEPTRON SIMPLE

model = keras.Sequential([
    keras.layers.Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    keras.layers.Dense(32, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")  # Capa de salida binaria
])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                192
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,305
# Trainable params: 2,305
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Compilar el modelo
optimizer = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss=keras.losses.BinaryCrossentropy(), optimizer=optimizer, metrics=["accuracy"])

# %%
#Entrenar el modelo.

history = model.fit(X_train_resampled, y_train_resampled, epochs=132, batch_size=16)
# Out:
# Epoch 1/132
# 10/10 [==============================] - 1s 2ms/step - loss: 0.7155 - accuracy: 0.4125
# Epoch 2/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7088 - accuracy: 0.4125
# Epoch 3/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7023 - accuracy: 0.4062
# Epoch 4/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6958 - accuracy: 0.4250
# Epoch 5/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.4938
# Epoch 6/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5500
# Epoch 7/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6767 - accuracy: 0.6062
# Epoch 8/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6706 - accuracy: 0.6750
# Epoch 9/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6645 - accuracy: 0.7750
# Epoch 10/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.8625
# Epoch 11/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6526 - accuracy: 0.8938
# Epoch 12/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6473 - accuracy: 0.9312
# Epoch 13/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6417 - accuracy: 0.9375
# Epoch 14/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6364 - accuracy: 0.9375
# Epoch 15/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6312 - accuracy: 0.9375
# Epoch 16/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6261 - accuracy: 0.9375
# Epoch 17/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6209 - accuracy: 0.9375
# Epoch 18/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6159 - accuracy: 0.9312
# Epoch 19/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6109 - accuracy: 0.9312
# Epoch 20/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6059 - accuracy: 0.9375
# Epoch 21/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6011 - accuracy: 0.9375
# Epoch 22/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5963 - accuracy: 0.9375
# Epoch 23/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5914 - accuracy: 0.9375
# Epoch 24/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5866 - accuracy: 0.9250
# Epoch 25/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5818 - accuracy: 0.9250
# Epoch 26/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5769 - accuracy: 0.9250
# Epoch 27/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5721 - accuracy: 0.9250
# Epoch 28/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5672 - accuracy: 0.9250
# Epoch 29/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5623 - accuracy: 0.9375
# Epoch 30/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5576 - accuracy: 0.9375
# Epoch 31/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5527 - accuracy: 0.9375
# Epoch 32/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5478 - accuracy: 0.9375
# Epoch 33/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5432 - accuracy: 0.9375
# Epoch 34/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5384 - accuracy: 0.9312
# Epoch 35/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5336 - accuracy: 0.9312
# Epoch 36/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5289 - accuracy: 0.9312
# Epoch 37/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5241 - accuracy: 0.9312
# Epoch 38/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5195 - accuracy: 0.9312
# Epoch 39/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5148 - accuracy: 0.9312
# Epoch 40/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5101 - accuracy: 0.9312
# Epoch 41/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5054 - accuracy: 0.9250
# Epoch 42/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5008 - accuracy: 0.9250
# Epoch 43/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4961 - accuracy: 0.9250
# Epoch 44/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4913 - accuracy: 0.9312
# Epoch 45/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4868 - accuracy: 0.9312
# Epoch 46/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4822 - accuracy: 0.9312
# Epoch 47/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4776 - accuracy: 0.9312
# Epoch 48/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.9312
# Epoch 49/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4685 - accuracy: 0.9312
# Epoch 50/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4639 - accuracy: 0.9312
# Epoch 51/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4594 - accuracy: 0.9312
# Epoch 52/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4549 - accuracy: 0.9312
# Epoch 53/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.9312
# Epoch 54/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4459 - accuracy: 0.9312
# Epoch 55/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4414 - accuracy: 0.9312
# Epoch 56/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.9312
# Epoch 57/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.9312
# Epoch 58/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.9312
# Epoch 59/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4237 - accuracy: 0.9312
# Epoch 60/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4194 - accuracy: 0.9312
# Epoch 61/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4151 - accuracy: 0.9312
# Epoch 62/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4108 - accuracy: 0.9312
# Epoch 63/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.9312
# Epoch 64/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4019 - accuracy: 0.9312
# Epoch 65/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.9312
# Epoch 66/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.9312
# Epoch 67/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.9312
# Epoch 68/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3843 - accuracy: 0.9312
# Epoch 69/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.9312
# Epoch 70/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3759 - accuracy: 0.9375
# Epoch 71/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3719 - accuracy: 0.9375
# Epoch 72/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3679 - accuracy: 0.9375
# Epoch 73/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3638 - accuracy: 0.9375
# Epoch 74/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3597 - accuracy: 0.9375
# Epoch 75/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3558 - accuracy: 0.9375
# Epoch 76/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.9375
# Epoch 77/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3481 - accuracy: 0.9375
# Epoch 78/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3443 - accuracy: 0.9375
# Epoch 79/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3406 - accuracy: 0.9375
# Epoch 80/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3370 - accuracy: 0.9375
# Epoch 81/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.9375
# Epoch 82/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3296 - accuracy: 0.9438
# Epoch 83/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3261 - accuracy: 0.9438
# Epoch 84/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3225 - accuracy: 0.9438
# Epoch 85/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3191 - accuracy: 0.9438
# Epoch 86/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3156 - accuracy: 0.9438
# Epoch 87/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3123 - accuracy: 0.9438
# Epoch 88/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3089 - accuracy: 0.9438
# Epoch 89/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3055 - accuracy: 0.9438
# Epoch 90/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3023 - accuracy: 0.9438
# Epoch 91/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2992 - accuracy: 0.9438
# Epoch 92/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2960 - accuracy: 0.9438
# Epoch 93/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2929 - accuracy: 0.9438
# Epoch 94/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2898 - accuracy: 0.9438
# Epoch 95/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2867 - accuracy: 0.9438
# Epoch 96/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2838 - accuracy: 0.9438
# Epoch 97/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2809 - accuracy: 0.9438
# Epoch 98/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.9438
# Epoch 99/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2750 - accuracy: 0.9438
# Epoch 100/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2722 - accuracy: 0.9438
# Epoch 101/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.9500
# Epoch 102/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2667 - accuracy: 0.9625
# Epoch 103/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2641 - accuracy: 0.9625
# Epoch 104/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2614 - accuracy: 0.9625
# Epoch 105/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2588 - accuracy: 0.9625
# Epoch 106/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.9625
# Epoch 107/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.9625
# Epoch 108/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2514 - accuracy: 0.9625
# Epoch 109/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.9625
# Epoch 110/132
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2464 - accuracy: 0.9625
# Epoch 111/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2441 - accuracy: 0.9625
# Epoch 112/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.9625
# Epoch 113/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2395 - accuracy: 0.9625
# Epoch 114/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2371 - accuracy: 0.9688
# Epoch 115/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2349 - accuracy: 0.9688
# Epoch 116/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2328 - accuracy: 0.9688
# Epoch 117/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2306 - accuracy: 0.9688
# Epoch 118/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2285 - accuracy: 0.9688
# Epoch 119/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2265 - accuracy: 0.9688
# Epoch 120/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2244 - accuracy: 0.9688
# Epoch 121/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2224 - accuracy: 0.9688
# Epoch 122/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2204 - accuracy: 0.9688
# Epoch 123/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2184 - accuracy: 0.9688
# Epoch 124/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2165 - accuracy: 0.9688
# Epoch 125/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2147 - accuracy: 0.9750
# Epoch 126/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2127 - accuracy: 0.9750
# Epoch 127/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2109 - accuracy: 0.9750
# Epoch 128/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9750
# Epoch 129/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2073 - accuracy: 0.9750
# Epoch 130/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2056 - accuracy: 0.9750
# Epoch 131/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2038 - accuracy: 0.9750
# Epoch 132/132
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2021 - accuracy: 0.9750

# %%
#Ver los resultados
print(model.evaluate(X_test, y_test))
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2508 - accuracy: 1.0000
# [0.2507900595664978, 1.0]

# %%
#Evaluar el modelo y ver su presición y saber si es confiable.
sample = X_test[4, :]
prediction = model.predict(np.expand_dims(sample,axis=0))

prediction = 0 if prediction<=0.5 else 1

print(prediction)
# Out:
# 1/1 [==============================] - 0s 120ms/step
# 0

# %%
print(y_test [0]== prediction)
# Out:
# False

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=[112,8])
plt.scatter(df.iloc[:,0].values,df.iloc[:,1].values,
            c= df.iloc[:,-1].values)
plt.show()


values=pd.DataFrame(history.history)
values.plot()
plt.show()
